# %%
# !git clone https://github.com/milesperry81/Data.git
# Out:
# Cloning into 'Data'...
# remote: Enumerating objects: 54, done.
# remote: Counting objects: 100% (54/54), done.
# remote: Compressing objects: 100% (53/53), done.
# remote: Total 54 (delta 21), reused 0 (delta 0), pack-reused 0
# Unpacking objects: 100% (54/54), done.

# %%
# Import the required packages.
import tensorflow as tf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# Set randown seed values.
tf.random.set_seed(51)
np.random.seed(51)

# Import the individual csv files.
df1 = pd.read_csv('/content/Data/Prices_2016_09_2017_02.csv')
df2 = pd.read_csv('/content/Data/Prices_2017_03_2017_08.csv')
df3 = pd.read_csv('/content/Data/Prices_2017_09_2018_02.csv')
df4 = pd.read_csv('/content/Data/Prices_2018_03_2018_08.csv')
#df5 = pd.read_csv('/content/Data/Prices_2018_09_2019_01.csv')
#df1.head()

# %%
# Extract the required columns from the CSV files before concatenating them.
df1_loc = df1.loc[:, 'Site':'28/02/2017']
df2_loc = df2.loc[:, '1/03/2017':'31/08/2017']
df3_loc = df3.loc[:, '1/09/2017':'28/02/2018']
df4_loc = df4.loc[:, '1/03/2018':'31/08/2018']
#df5_loc = df5.loc[:, '1/09/2018':'31/01/2019']

# Concatenate the CSV data into a single data frame.
#df = pd.concat([df1_loc, df2_loc, df3_loc, df4_loc, df5_loc], axis=1, sort=True)
df = pd.concat([df1_loc, df2_loc, df3_loc, df4_loc], axis=1, sort=True)

# %%
# Remove rows the data with zero values in the first column.
sites_index = []

for i in range(df.shape[0]):
  #Find index of sites with zero value to start.
  if df.loc[i][1] == 0.00:
    sites_index.append(i)

# Drop sites with zero starting price.
df = df.drop(sites_index)

# %%
# Reset the index after removing data with zeros
df = df.reset_index(drop=True)
df.head()
# Out:
#                         Site  1/09/2016  ...  30/08/2018  31/08/2018
# 0         7-Eleven Adamstown       98.9  ...       157.9       151.9
# 1  7-Eleven Albion Park Rail      105.7  ...       159.4       154.9
# 2          7-Eleven Argenton      101.9  ...       152.9       152.9
# 3         7-Eleven Arncliffe      107.7  ...       159.4       158.9
# 4      7-Eleven Arndell Park      103.9  ...       159.4       159.4
#
# [5 rows x 731 columns]

# %%
data_start_date = df.columns[1]
data_end_date = df.columns[-1]
print('Data ranges from %s to %s' % (data_start_date, data_end_date))
# Out:
# Data ranges from 1/09/2016 to 31/08/2018

# %%
# Function to plot time series data.
def plot_random_series(df, n_series):
    
    sample = df.sample(n_series, random_state=8)
    page_labels = sample['Site'].tolist()
    series_samples = sample.loc[:,data_start_date:data_end_date]
    
    plt.figure(figsize=(10,6))
    
    for i in range(series_samples.shape[0]):
        pd.Series(series_samples.iloc[i]).astype(np.float64).plot(linewidth=1.5)
    
    plt.title('Randomly Selected Site Daily Prices Over Time')
    plt.legend(page_labels)
    plt.xlabel("Date")
    plt.ylabel("Cents/litre")
    
plot_random_series(df, 6)

# %%
from datetime import timedelta

# Size of the prediction interval.
pred_steps = 60

# Size of the historic data input windows.
window = 600

pred_length = timedelta(pred_steps)
window_length = timedelta(window) 

# Find first and last date of the dateset.
first_day = pd.to_datetime(data_start_date, dayfirst=True) # convert to date and time.
last_day = pd.to_datetime(data_end_date, dayfirst=True) # convert to date and time.

# Find start of the final prediction window.
final_pred_start = last_day - pred_length + timedelta(1) # end - X days + 1 day.

# Find start and end of the final historic data window.
final_history_start = final_pred_start - window_length
final_history_end = final_pred_start - timedelta(1)

# %%
# Ensure there are no milleseconds on the timestamps. 

first_day = first_day.strftime("%Y-%m-%d %H:%M:%S")
last_day = last_day.strftime("%Y-%m-%d %H:%M:%S")

final_pred_start = final_pred_start.strftime("%Y-%m-%d %H:%M:%S")

final_history_start = final_history_start.strftime("%Y-%m-%d %H:%M:%S")
final_history_end = final_history_end.strftime("%Y-%m-%d %H:%M:%S")

# %%
print("Last history window:",final_history_start, '-',final_history_end)
print('Last prediction window:', final_pred_start, '-', last_day)

print('\nHistoric window interval:', window_length.days)
print('Prediction interval:', pred_length.days)
# Out:
# Last history window: 2016-11-10 00:00:00 - 2018-07-02 00:00:00
# Last prediction window: 2018-07-03 00:00:00 - 2018-08-31 00:00:00
#
# Historic window interval: 600
# Prediction interval: 60

# %%
# Create indicies from the date column headings.
date_to_index = pd.Series(index=pd.Index([pd.to_datetime(c,dayfirst=True) for c in df.columns[1:]]),
                          data=[i for i in range(len(df.columns[1:]))])

# Function to split the main data series into training, validation and test.
def split_series(series_array, split = 0.1):

    split_num_val = int(series_array.shape[0]-((series_array.shape[0]*split)*2))
    split_num_test = int(series_array.shape[0]-(series_array.shape[0]*split))

    train_series = series_array[:split_num_val,:]
    validation_series = series_array[split_num_val:split_num_test,:]
    test_series = series_array[split_num_test:,:]
    
    return train_series, validation_series, test_series

# Function to pull a time frame of data from a series array.
def get_time_block_series(series_array, date_to_index, start_date, end_date):
    
    # Find indicies for the requested date range.
    inds = date_to_index[start_date:end_date]
    # Return the data series for the relevant date range using the indicies.
    return series_array[:,inds]

# Function to normalise a series array for training.
def transform_series_train(series_array):
       
    series_mean = series_array.mean().reshape(-1,1)
    series_std = series_array.std().reshape(-1,1)
    series_array = (series_array - series_mean)/series_std
    series_array = series_array.reshape((series_array.shape[0],series_array.shape[1], 1))

    return series_array, series_mean, series_std

# Function to normalise a series array using the mean and std dev from training.
def transform_series_other(series_array, train_series_mean, train_series_std):
    
    series_array = (series_array - train_series_mean)/train_series_std
    series_array = series_array.reshape((series_array.shape[0],series_array.shape[1], 1))
    
    return series_array

# %%
#Create numpy array of the series values.
series_array = df[df.columns[1:]].values

#Shuffle the array.
np.random.shuffle(series_array)

# Create a series array from the data using the last historic window and prediction 
# intervals. This data will be shared amongst the validation and test data. These time
# period will be unseen by the algorithm during training. 
unseen_data = get_time_block_series(series_array, date_to_index, final_history_start, last_day)

# The time periods will be segmented into train, validation and test data. 
seen_data = get_time_block_series(series_array, date_to_index, first_day, final_history_end)

print("Shape of unseen data: ",unseen_data.shape)
print("Shape of seen data: ",seen_data.shape)
# Out:
# Shape of unseen data:  (1307, 660)
# Shape of seen data:  (1307, 670)

# %%
# Create more windows of data from the seen data series.

# Function to segment the data into smaller time windows.
def walk_forward(series,window_size,prediction_steps,increment_steps=2):
  
  # Determine the number of forward steps we can take when creating a new series of data.
  forward_steps = series.shape[1]-(window_size+prediction_steps)

  # Assign the first set of data series to the new series array.
  new_series = series[:,:window_size+prediction_steps]

  # Take steps forward in time to create more time windows.
  for i in range(increment_steps,forward_steps,increment_steps):
      new_series = np.concatenate((new_series, series[:,i:i+window_size+prediction_steps]), axis=0)

  return new_series

# Run the walk forward segmentation.
new_series = walk_forward(seen_data,window,pred_steps,1)

# Shuffle the newly segmented data.
np.random.shuffle(new_series)

print("Pre segmentation series dimension: ",seen_data.shape)
print("Post segmentation series dimension: ",np.array(new_series).shape)
# Out:
# Pre segmentation series dimension:  (1307, 670)
# Post segmentation series dimension:  (13070, 660)

# %%
# Split the train and validation series from each other.
train_series, validation_series, test_series = split_series(new_series, split = 0.1)

# Split the unseen data in half and then add to validation and test.
unseen_split = unseen_data.shape[0]//2

# Add unseen data to the validation and test series.
validation_series = np.concatenate((validation_series, unseen_data[:unseen_split,:]), axis=0)
test_series = np.concatenate((test_series, unseen_data[unseen_split:,:]), axis=0)

#TRAINING DATA INPUTS AND TARGETS

# Normalise the training input data.
train_input_data, train_series_mean, train_series_std = transform_series_train(train_series[:,:window])
# Normalise the training target data.
train_target_data = transform_series_other(train_series[:,window:], train_series_mean, train_series_std)

#VALIDATION DATA INPUTS AND TARGETS.

# Normalise the validation input data.
validation_input_data = transform_series_other(validation_series[:,:window],train_series_mean, train_series_std)
# Normalise the validation target data.
validation_target_data = transform_series_other(validation_series[:,window:], train_series_mean, train_series_std)

# %%
#Training history (m,time_steps,1)
print("Shape of the training history: ",train_input_data.shape)
#Training targets (m,pred_steps,1)
print("Shape of the training targets: ",train_target_data.shape)

#Validation history (m,time_steps,1)
print("Shape of the validation history: ",validation_input_data.shape)
#Validation targets (m,pred_steps,1)
print("Shape of the validation targets: ",validation_target_data.shape)
# Out:
# Shape of the training history:  (10456, 600, 1)
# Shape of the training targets:  (10456, 60, 1)
# Shape of the validation history:  (1960, 600, 1)
# Shape of the validation targets:  (1960, 60, 1)

# %%
# Define the model and train it. Use learning rate call back to get grasp 
# of the learning rate.

tf.keras.backend.clear_session()

# Define a simple LSTM as a baseline.
model = tf.keras.models.Sequential([
    tf.keras.layers.LSTM(8, input_shape=(None,1)),
    tf.keras.layers.Dense(1)
])

lr_schedule = tf.keras.callbacks.LearningRateScheduler(
    lambda epoch: 1e-6 * 10**(epoch / 20))

LEARNING_RATE = 1e-6
optimizer = tf.keras.optimizers.Adam(lr=LEARNING_RATE)

model.compile(optimizer='adam', loss='mae')

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, 8)                 320
# _________________________________________________________________
# dense (Dense)                (None, 1)                 9
# =================================================================
# Total params: 329
# Trainable params: 329
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Define the tensorflow data pipelines with a shuffle buffer and batches.
BUFFER_SIZE = 10000
BATCH_SIZE = 128

train_univariate = tf.data.Dataset.\
                      from_tensor_slices((train_input_data, train_target_data))
train_univariate = train_univariate.cache().shuffle(BUFFER_SIZE).\
                      batch(BATCH_SIZE).repeat()

val_univariate = tf.data.Dataset.\
            from_tensor_slices((validation_input_data, validation_target_data))
val_univariate = val_univariate.batch(BATCH_SIZE).repeat()

# %%
# Run the model with learning rate schedule callbacks to find good value.

EPOCHS = 100
EVALUATION_INTERVAL = train_input_data.shape[0]//BATCH_SIZE

history = model.fit(train_univariate,
                    epochs=EPOCHS,
                    steps_per_epoch=EVALUATION_INTERVAL,
                    validation_data=val_univariate,
                    validation_steps=50,
                    callbacks=[lr_schedule]
                    )
# Out:
# Epoch 1/100
# 81/81 [==============================] - 2s 24ms/step - loss: 1.8960 - val_loss: 1.8848 - lr: 1.0000e-06
# Epoch 2/100
# 81/81 [==============================] - 2s 24ms/step - loss: 1.
100
# 81/81 [==============================] - 2s 24ms/step - loss: 0.4045 - val_loss: 0.4379 - lr: 0.0112
# Epoch 83/100
# 81/81 [==============================] - 2s 25ms/step - loss: 0.3937 - val_loss: 0.4572 - lr: 0.0126
# Epoch 84/100
# 81/81 [==============================] - 2s 24ms/step - loss: 0.3790 - val_loss: 0.4605 - lr: 0.0141
# Epoch 85/100
# 81/81 [==============================] - 2s 25ms/step - loss: 0.3821 - val_loss: 0.4530 - lr: 0.0158
# Epoch 86/100
# 81/81 [==============================] - 2s 24ms/step - loss: 0.3943 - val_loss: 0.4567 - lr: 0.0178
# Epoch 87/100
# 81/81 [==============================] - 2s 24ms/step - loss: 0.3803 - val_loss: 0.4468 - lr: 0.0200
# Epoch 88/100
# 81/81 [==============================] - 2s 25ms/step - loss: 0.3996 - val_loss: 0.4438 - lr: 0.0224
# Epoch 89/100
# 81/81 [==============================] - 2s 25ms/step - loss: 0.3726 - val_loss: 0.4553 - lr: 0.0251
# Epoch 90/100
# 81/81 [==============================] - 2s 25ms/step - loss: 0.5158 - val_loss: 0.4933 - lr: 0.0282
# Epoch 91/100
# 81/81 [==============================] - 2s 25ms/step - loss: 0.4517 - val_loss: 0.4578 - lr: 0.0316
# Epoch 92/100
# 81/81 [==============================] - 2s 25ms/step - loss: 0.4216 - val_loss: 0.4429 - lr: 0.0355
# Epoch 93/100
# 81/81 [==============================] - 2s 25ms/step - loss: 0.4531 - val_loss: 0.5891 - lr: 0.0398
# Epoch 94/100
# 81/81 [==============================] - 2s 24ms/step - loss: 0.5293 - val_loss: 0.5430 - lr: 0.0447
# Epoch 95/100
# 81/81 [==============================] - 2s 24ms/step - loss: 0.4742 - val_loss: 0.4679 - lr: 0.0501
# Epoch 96/100
# 81/81 [==============================] - 2s 24ms/step - loss: 0.4543 - val_loss: 0.4697 - lr: 0.0562
# Epoch 97/100
# 81/81 [==============================] - 2s 25ms/step - loss: 0.4405 - val_loss: 0.4797 - lr: 0.0631
# Epoch 98/100
# 81/81 [==============================] - 2s 25ms/step - loss: 0.5036 - val_loss: 0.5624 - lr: 0.0708
# Epoch 99/100
# 81/81 [==============================] - 2s 24ms/step - loss: 0.5002 - val_loss: 0.5008 - lr: 0.0794
# Epoch 100/100
# 81/81 [==============================] - 2s 24ms/step - loss: 0.5081 - val_loss: 0.5390 - lr: 0.0891

# %%
# Plot the sampled learning rates versus loss.
plt.semilogx(history.history["lr"], history.history["loss"])
plt.axis([1e-6, 1e-0, 0, 2])
# Out:
# (1e-06, 1.0, 0.0, 2.0)

# %%
# Run the model with the chosen learning rate
tf.keras.backend.clear_session()

LEARNING_RATE = 1e-3
optimizer = tf.keras.optimizers.Adam(lr=LEARNING_RATE)
model.compile(optimizer='adam', loss='mae')

EPOCHS = 400
EVALUATION_INTERVAL = train_input_data.shape[0]//BATCH_SIZE
VALIDATION_STEPS = validation_input_data.shape[0]//BATCH_SIZE

history = model.fit(train_univariate,
                    epochs=EPOCHS,
                    steps_per_epoch=EVALUATION_INTERVAL,
                    validation_data=val_univariate,
                    validation_steps=VALIDATION_STEPS)
# Out:
# Epoch 1/400
# 81/81 [==============================] - 2s 25ms/step - loss: 1.3237 - val_loss: 0.7976
# Epoch 2/400
# 81/81 [==============================] - 2s 21ms/step - loss: 0.6207 - val_loss: 0.5315
# Epoch 3/400
# 81/81 [==============================] - 2s 22ms/step - loss: 0.4723 - val_loss: 0.5023
# Epoch 4/400
# 81/81 [==============================] - 2s 21ms/step - loss: 0.4459 - val_loss: 0.4741
# Epoch 5/400
# 81/81 [==============================] - 2s 21ms/step - loss: 0.4236 - val_loss: 0.4595
# Epoch 6/400
# 81/81 [==============================] - 2s 21ms/step - loss: 0.4159 - val_loss: 0.4570
# Epoch 7/400
# 81/81 [==============================] - 2s 21ms/step - loss: 0.4080 - val_loss: 0.4482
# Epoch 8/400
# 81/81 [==============================] - 2s 21ms/step - loss: 0.4026 - val_loss: 0.4462
# Epoch 9/400
# 81/81 [==============================] - 2s 21ms/step - loss: 0.3994 - val_loss: 0.4424
# Epoch 10/400
# 81/81 [==============================] - 2s 21ms/step - loss: 0.3937 - val_loss: 0.4427
# Epoch 11/400
# 81/81 [==============================] - 2s 20ms/step - loss: 0.3940 - val_loss: 0.4403
# Epoch 12/400
# 81/81 [==============================] - 2s 20ms/step - loss: 0.3927 - val_loss: 0.4391
# Epoch 13/400
# 81/81 [==============================] - 2s 21ms/step - loss: 0.3899 - val_loss: 0.4395
# Epoch 14/400
# 81/81 [==============================] - 2s 21ms/step - loss: 0.3882 - val_loss: 0.4399
# Epoch 15/400
# 81/81 [==============================] - 2s 20ms/step - loss: 0.3875 - val_loss: 0.4400
# Epoch 16/400
# 81/81 [==============================] - 2s 21ms/step - loss: 0.3872 - val_loss: 0.4407
# Epoch 17/400
# 81/81 [==============================] - 2s 21ms/step - loss: 0.3860 - val_loss: 0.4398
# Epoch 18/400
# 81/81 [==============================] - 2s 21ms/step - loss: 0.3857 - val_loss: 0.4434
# Epoch 19/400
# 81/81 [==============================] - 2s 20ms/step - loss: 0.3854 - val_loss: 0.4465
# Epoch 20/400
# 81/81 [==============================] - 2s 21ms/step - loss: 0.3865 - val_loss: 0.4446
# Epoch 21/400
# 81/81 [==============================] - 2s 20ms/step - loss: 0.3792 - val_loss: 0.4433
# Epoch 22/400
# 81/81 [==============================] - 2s 21ms/step - loss: 0.3843 - val_loss: 0.4437
# Epoch 23/400
# 81/81 [==============================] - 2s 20ms/step - loss: 0.3823 - val_loss: 0.4480
# Epoch 24/400
# 81/81 [==============================] - 2s 21ms/step - loss: 0.3799 - val_loss: 0.4460
# Epoch 25/400
# 81/81 [==============================] - 2s 21ms/step - loss: 0.3808 - val_loss: 0.4474
# Epoch 26/400
# 81/81 [==============================] - 2s 21ms/step - loss: 0.3775 - val_loss: 0.4503
# Epoch 27/400
# 81/81 [==============================] - 2s 21ms/step - loss: 0.3787 - val_loss: 0.4434
# Epoch 28/400
# 81/81 [==============================] - 2s 21ms/step - loss: 0.3832 - val_loss: 0.4396
# Epoch 29/400
# 81/81 [==============================] - 2s 21ms/step - loss: 0.3783 - val_loss: 0.4523
# Epoch 30/400
# 81/81 [==============================] - 2s 21ms/step - loss: 0.3713 - val_loss: 0.4472
# Epoch 31/400
# 81/81 [==============================] - 2s 21ms/step - loss: 0.3768 - val_loss: 0.4495
# Epoch 32/400
# 81/81 [==============================] - 2s 20ms/step - loss: 0.3728 - val_loss: 0.4434
# Epoch 33/400
# 81/81 [==============================] - 2s 21ms/step - loss: 0.3717 - val_loss: 0.4468
# Epoch 34/400
# 81/81 [==============================] - 2s 21ms/step - loss: 0.3735 - val_loss: 0.4548
# Epoch 35/400
# 81/81 [==============================] - 2s 21ms/step - loss: 0.3732 - val_loss: 0.4542
# Epoch 36/400
# 81/81 [==============================] - 2s 20ms/step - loss: 0.3724 - val_loss: 0.4545
# Epoch 37/400
# 81/81 [==============================] - 2s 21ms/step - loss: 0.3692 - val_loss: 0.4504
# Epoch 38/400
# 81/81 [==============================] - 2s 21ms/step - loss: 0.3681 - val_loss: 0.4525
# Epoch 39/400
# 81/81 [==============================] - 2s 21ms/step - loss: 0.3816 - val_loss: 0.5160
# Epoch 40/400
# 81/81 [==============================] - 2s 20ms/step - loss: 0.4035 - val_loss: 0.4470
# Epoch 41/400
# 81/81 [==============================] - 2s 20ms/step - loss: 0.3778 - val_loss: 0.4488
# Epoch 42/400
# 81/81 [==============================] - 2s 21ms/step - loss: 0.3743 - val_loss: 0.4529
# Epoch 43/400
# 81/81 [==============================] - 2s 21ms/step - loss: 0.3694 - val_loss: 0.4559
# Epoch 44/400
# 81/81 [==============================] - 2s 21ms/step - loss: 0.3735 - val_loss: 0.4541
# Epoch 45/400
# 81/81 [==============================] - 2s 21ms/step - loss: 0.3683 - val_loss: 0.4559
# Epoch 46/400
# 81/81 [==============================] - 2s 21ms/step - loss: 0.3682 - val_loss: 0.4561
# Epoch 47/400
# 81/81 [==============================] - 2s 21ms/step - loss: 0.3659 - val_loss: 0.4557
# Epoch 48/400
# 81/81 [==============================] - 2s 21ms/step - loss: 0.3647 - val_loss: 0.4605
# Epoch 49/400
# 81/81 [==============================] - 2s 26ms/step - loss: 0.3664 - val_loss: 0.4598
# Epoch 50/400
# 81/81 [==============================] - 2s 21ms/step - loss: 0.3666 - val_loss: 0.4562
# Epoch 51/400
# 81/81 [==============================] - 2s 21ms/step - loss: 0.3642 - val_loss: 0.4589
# Epoch 52/400
# 81/81 [==============================] - 2s 21ms/step - loss: 0.3636 - val_loss: 0.4555
# Epoch 53/400
# 81/81 [==============================] - 2s 21ms/step - loss: 0.3680 - val_loss: 0.4574
# Epoch 54/400
# 81/81 [==============================] - 2s 21ms/step - loss: 0.3621 - val_loss: 0.4576
# Epoch 55/400
# 81/81 [==============================] - 2s 21ms/step - loss: 0.3644 - val_loss: 0.4569
# Epoch 56/400
# 81/81 [==============================] - 2s 21ms/step - loss: 0.3650 - val_loss: 0.4591
# Epoch 57/400
# 81/81 [==============================] - 2s 22ms/step - loss: 0.3641 - val_loss: 0.4569
# Epoch 58/400
# 81/81 [==============================] - 2s 21ms/step - loss: 0.3628 - val_loss: 0.4583
# Epoch 59/400
# 81/81 [==============================] - 2s 21ms/step - loss: 0.3641 - val_loss: 0.4544
# Epoch 60/400
# 81/81 [==============================] - 2s 22ms/step - loss: 0.3658 - val_loss: 0.4556
# Epoch 61/400
# 81/81 [==============================] - 2s 22ms/step - loss: 0.3606 - val_loss: 0.4641
# Epoch 62/400
# 81/81 [==============================] - 2s 21ms/step - loss: 0.3667 - val_loss: 0.4595
# Epoch 63/400
# 81/81 [==============================] - 2s 21ms/step - loss: 0.3609 - val_loss: 0.4608
# Epoch 64/400
# 81/81 [==============================] - 2s 21ms/step - loss: 0.3625 - val_loss: 0.4594
# Epoch 65/400
# 81/81 [==============================] - 2s 21ms/step - loss: 0.3636 - val_loss: 0.4568
# Epoch 66/400
# 81/81 [==============================] - 2s 21ms/step - loss: 0.3598 - val_loss: 0.4583
# Epoch 67/400
# 81/81 [==============================] - 2s 22ms/step - loss: 0.3635 - val_loss: 0.4567
# Epoch 68/400
# 81/81 [==============================] - 2s 22ms/step - loss: 0.3617 - val_loss: 0.4596
# Epoch 69/400
# 81/81 [==============================] - 2s 21ms/step - loss: 0.3642 - val_loss: 0.4606
# Epoch 70/400
# 81/81 [==============================] - 2s 21ms/step - loss: 0.3602 - val_loss: 0.4578
# Epoch 71/400
# 81/81 [==============================] - 2s 21ms/step - loss: 0.3608 - val_loss: 0.4600
# Epoch 72/400
# 81/81 [==============================] - 2s 22ms/step - loss: 0.3614 - val_loss: 0.4580
# Epoch 73/400
# 81/81 [==============================] - 2s 21ms/step - loss: 0.3676 - val_loss: 0.4564
# Epoch 74/400
# 81/81 [==============================] - 2s 21ms/step - loss: 0.3603 - val_loss: 0.4574
# Epoch 75/400
# 81/81 [==============================] - 2s 22ms/step - loss: 0.3624 - val_loss: 0.4582
# Epoch 76/400
# 81/81 [==============================] - 2s 21ms/step - loss: 0.3605 - val_loss: 0.4567
# Epoch 77/400
# 81/81 [==============================] - 2s 21ms/step - loss: 0.3605 - val_loss: 0.4539
# Epoch 78/400
# 81/81 [==============================] - 2s 21ms/step - loss: 0.3614 - val_loss: 0.4593
# Epoch 79/400
# 81/81 [==============================] - 2s 21ms/step - loss: 0.3607 - val_loss: 0.4555
# Epoch 80/400
# 81/81 [==============================] - 2s 21ms/step - loss: 0.3607 - val_loss: 0.4577
# Epoch 81/400
# 81/81 [==============================] - 2s 21ms/step - loss: 0.3607 - val_loss: 0.4607
# Epoch 82/400
# 81/81 [==============================] - 2s 22ms/step - loss: 0.3611 - val_loss: 0.4574
# Epoch 83/400
# 81/81 [==============================] - 2s 21ms/step - loss: 0.3604 - val_loss: 0.4614
# Epoch 84/400
# 81/81 [==============================] - 2s 21ms/step - loss: 0.3597 - val_loss: 0.4583
# Epoch 85/400
# 81/81 [==============================] - 2s 21ms/step - loss: 0.3600 - val_loss: 0.4624
# Epoch 86/400
# 81/81 [==============================] - 2s 22ms/step - loss: 0.3605 - val_loss: 0.4599
# Epoch 87/400
# 81/81 [==============================] - 2s 21ms/step - loss: 0.3587 - val_loss: 0.4610
# Epoch 88/400
# 81/81 [==============================] - 2s 22ms/step - loss: 0.3601 - val_loss: 0.4633
# Epoch 89/400
# 81/81 [==============================] - 2s 22ms/step - loss: 0.3601 - val_loss: 0.4600
# Epoch 90/400
# 81/81 [==============================] - 2s 21ms/step - loss: 0.3854 - val_loss: 0.5713
# Epoch 91/400
# 81/81 [==============================] - 2s 21ms/step - loss: 0.4266 - val_loss: 0.4871
# Epoch 92/400
# 81/81 [==============================] - 2s 21ms/step - loss: 0.3975 - val_loss: 0.4558
# Epoch 93/400
# 81/81 [==============================] - 2s 21ms/step - loss: 0.3786 - val_loss: 0.4538
# Epoch 94/400
# 81/81 [==============================] - 2s 21ms/step - loss: 0.3623 - val_loss: 0.4536
# Epoch 95/400
# 81/81 [==============================] - 2s 21ms/step - loss: 0.3594 - val_loss: 0.4542
# Epoch 96/400
# 81/81 [==============================] - 2s 21ms/step - loss: 0.3828 - val_loss: 0.4815
# Epoch 97/400
# 81/81 [==============================] - 2s 22ms/step - loss: 0.3969 - val_loss: 0.4501
# Epoch 98/400
# 81/81 [==============================] - 2s 21ms/step - loss: 0.3831 - val_loss: 0.4500
# Epoch 99/400
# 81/81 [==============================] - 2s 21ms/step - loss: 0.3784 - val_loss: 0.4474
# Epoch 100/400
# 81/81 [==============================] - 2s 21ms/step - loss: 0.3720 - val_loss: 0.4552
# Epoch 101/400
# 81/81 [==============================] - 2s 22ms/step - loss: 0.3669 - val_loss: 0.4471
# Epoch 102/400
# 81/81 [==============================] - 2s 21ms/step - loss: 0.3663 - val_loss: 0.4505
# Epoch 103/400
# 81/81 [==============================] - 2s 21ms/step - loss: 0.3638 - val_loss: 0.4571
# Epoch 104/400
# 81/81 [==============================] - 2s 22ms/step - loss: 0.3609 - val_loss: 0.4572
# Epoch 105/400
# 81/81 [==============================] - 2s 21ms/step - loss: 0.3641 - val_loss: 0.4579
# Epoch 106/400
# 81/81 [==============================] - 2s 21ms/step - loss: 0.3593 - val_loss: 0.4597
# Epoch 107/400
# 81/81 [==============================] - 2s 22ms/step - loss: 0.3623 - val_loss: 0.4604
# Epoch 108/400
# 81/81 [==============================] - 2s 22ms/step - loss: 0.3603 - val_loss: 0.4591
# Epoch 109/400
# 81/81 [==============================] - 2s 22ms/step - loss: 0.3698 - val_loss: 0.4563
# Epoch 110/400
# 81/81 [==============================] - 2s 22ms/step - loss: 0.3569 - val_loss: 0.4584
# Epoch 111/400
# 81/81 [==============================] - 2s 22ms/step - loss: 0.3597 - val_loss: 0.4598
# Epoch 112/400
# 81/81 [==============================] - 2s 22ms/step - loss: 0.3622 - val_loss: 0.4623
# Epoch 113/400
# 81/81 [==============================] - 2s 21ms/step - loss: 0.3568 - val_loss: 0.4594
# Epoch 114/400
# 81/81 [==============================] - 2s 21ms/step - loss: 0.3605 - val_loss: 0.4606
# Epoch 115/400
# 81/81 [==============================] - 2s 21ms/step - loss: 0.3587 - val_loss: 0.4620
# Epoch 116/400
# 81/81 [==============================] - 2s 21ms/step - loss: 0.3601 - val_loss: 0.4596
# Epoch 117/400
# 81/81 [==============================] - 2s 21ms/step - loss: 0.3618 - val_loss: 0.4578
# Epoch 118/400
# 81/81 [==============================] - 2s 22ms/step - loss: 0.3574 - val_loss: 0.4614
# Epoch 119/400
# 81/81 [==============================] - 2s 21ms/step - loss: 0.3571 - val_loss: 0.4640
# Epoch 120/400
# 81/81 [==============================] - 2s 22ms/step - loss: 0.3598 - val_loss: 0.4667
# Epoch 121/400
# 81/81 [==============================] - 2s 22ms/step - loss: 0.3631 - val_loss: 0.4663
# Epoch 122/400
# 81/81 [==============================] - 2s 22ms/step - loss: 0.3955 - val_loss: 0.4875
# Epoch 123/400
# 81/81 [==============================] - 2s 22ms/step - loss: 0.4025 - val_loss: 0.4473
# Epoch 124/400
# 81/81 [==============================] - 2s 21ms/step - loss: 0.3935 - val_loss: 0.4499
# Epoch 125/400
# 81/81 [==============================] - 2s 21ms/step - loss: 0.3862 - val_loss: 0.4481
# Epoch 126/400
# 81/81 [==============================] - 2s 21ms/step - loss: 0.3901 - val_loss: 0.4548
# Epoch 127/400
# 81/81 [==============================] - 2s 22ms/step - loss: 0.3850 - val_loss: 0.4504
# Epoch 128/400
# 81/81 [==============================] - 2s 21ms/step - loss: 0.3829 - val_loss: 0.4499
# Epoch 129/400
# 81/81 [==============================] - 2s 21ms/step - loss: 0.3851 - val_loss: 0.4549
# Epoch 130/400
# 81/81 [==============================] - 2s 21ms/step - loss: 0.3799 - val_loss: 0.4526
# Epoch 131/400
# 81/81 [==============================] - 2s 21ms/step - loss: 0.3776 - val_loss: 0.4602
# Epoch 132/400
# 81/81 [==============================] - 2s 21ms/step - loss: 0.3782 - val_loss: 0.4628
# Epoch 133/400
# 81/81 [==============================] - 2s 21ms/step - loss: 0.3697 - val_loss: 0.4649
# Epoch 134/400
# 81/81 [==============================] - 2s 21ms/step - loss: 0.3703 - val_loss: 0.4552
# Epoch 135/400
# 81/81 [==============================] - 2s 21ms/step - loss: 0.3647 - val_loss: 0.4591
# Epoch 136/400
# 81/81 [==============================] - 2s 21ms/step - loss: 0.3593 - val_loss: 0.4679
# Epoch 137/400
# 81/81 [==============================] - 2s 22ms/step - loss: 0.3601 - val_loss: 0.4640
# Epoch 138/400
# 81/81 [==============================] - 2s 21ms/step - loss: 0.3642 - val_loss: 0.4652
# Epoch 139/400
# 81/81 [==============================] - 2s 21ms/step - loss: 0.3582 - val_loss: 0.4684
# Epoch 140/400
# 81/81 [==============================] - 2s 21ms/step - loss: 0.3583 - val_loss: 0.4696
# Epoch 141/400
# 81/81 [==============================] - 2s 23ms/step - loss: 0.3581 - val_loss: 0.4707
# Epoch 142/400
# 81/81 [==============================] - 2s 21ms/step - loss: 0.3600 - val_loss: 0.4736
# Epoch 143/400
# 81/81 [==============================] - 2s 21ms/step - loss: 0.3586 - val_loss: 0.4703
# Epoch 144/400
# 81/81 [==============================] - 2s 21ms/step - loss: 0.3572 - val_loss: 0.4703
# Epoch 145/400
# 81/81 [==============================] - 2s 21ms/step - loss: 0.3566 - val_loss: 0.4727
# Epoch 146/400
# 81/81 [==============================] - 2s 21ms/step - loss: 0.3586 - val_loss: 0.4687
# Epoch 147/400
# 81/81 [==============================] - 2s 22ms/step - loss: 0.3593 - val_loss: 0.4740
# Epoch 148/400
# 81/81 [==============================] - 2s 21ms/step - loss: 0.3595 - val_loss: 0.4745
# Epoch 149/400
# 81/81 [==============================] - 2s 21ms/step - loss: 0.3577 - val_loss: 0.4736
# Epoch 150/400
# 81/81 [==============================] - 2s 21ms/step - loss: 0.3587 - val_loss: 0.4658
# Epoch 151/400
# 81/81 [==============================] - 2s 21ms/step - loss: 0.3572 - val_loss: 0.4651
# Epoch 152/400
# 81/81 [==============================] - 2s 21ms/step - loss: 0.3591 - val_loss: 0.4712
# Epoch 153/400
# 81/81 [==============================] - 2s 21ms/step - loss: 0.3587 - val_loss: 0.4703
# Epoch 154/400
# 81/81 [==============================] - 2s 21ms/step - loss: 0.3570 - val_loss: 0.4710
# Epoch 155/400
# 81/81 [==============================] - 2s 21ms/step - loss: 0.3583 - val_loss: 0.4710
# Epoch 156/400
# 81/81 [==============================] - 2s 21ms/step - loss: 0.3587 - val_loss: 0.5057
# Epoch 157/400
# 81/81 [==============================] - 2s 21ms/step - loss: 0.3616 - val_loss: 0.4667
# Epoch 158/400
# 81/81 [==============================] - 2s 22ms/step - loss: 0.3801 - val_loss: 0.4530
# Epoch 159/400
# 81/81 [==============================] - 2s 21ms/step - loss: 0.3633 - val_loss: 0.4728
# Epoch 160/400
# 81/81 [==============================] - 2s 21ms/step - loss: 0.3582 - val_loss: 0.4715
# Epoch 161/400
# 81/81 [==============================] - 2s 22ms/step - loss: 0.3577 - val_loss: 0.4680
# Epoch 162/400
# 81/81 [==============================] - 2s 22ms/step - loss: 0.3568 - val_loss: 0.4670
# Epoch 163/400
# 81/81 [==============================] - 2s 21ms/step - loss: 0.3570 - val_loss: 0.4704
# Epoch 164/400
# 81/81 [==============================] - 2s 21ms/step - loss: 0.3583 - val_loss: 0.4664
# Epoch 165/400
# 81/81 [==============================] - 2s 21ms/step - loss: 0.3609 - val_loss: 0.4562
# Epoch 166/400
# 81/81 [==============================] - 2s 22ms/step - loss: 0.3600 - val_loss: 0.4608
# Epoch 167/400
# 81/81 [==============================] - 2s 21ms/step - loss: 0.3615 - val_loss: 0.4602
# Epoch 168/400
# 81/81 [==============================] - 2s 21ms/step - loss: 0.3561 - val_loss: 0.4643
# Epoch 169/400
# 81/81 [==============================] - 2s 22ms/step - loss: 0.3598 - val_loss: 0.4644
# Epoch 170/400
# 81/81 [==============================] - 2s 21ms/step - loss: 0.3564 - val_loss: 0.4649
# Epoch 171/400
# 81/81 [==============================] - 2s 21ms/step - loss: 0.4444 - val_loss: 0.5516
# Epoch 172/400
# 81/81 [==============================] - 2s 21ms/step - loss: 0.4552 - val_loss: 0.5342
# Epoch 173/400
# 81/81 [==============================] - 2s 21ms/step - loss: 0.4245 - val_loss: 0.5044
# Epoch 174/400
# 81/81 [==============================] - 2s 21ms/step - loss: 0.4000 - val_loss: 0.4891
# Epoch 175/400
# 81/81 [==============================] - 2s 21ms/step - loss: 0.3923 - val_loss: 0.4784
# Epoch 176/400
# 81/81 [==============================] - 2s 21ms/step - loss: 0.3851 - val_loss: 0.4759
# Epoch 177/400
# 81/81 [==============================] - 2s 22ms/step - loss: 0.3864 - val_loss: 0.4790
# Epoch 178/400
# 81/81 [==============================] - 2s 21ms/step - loss: 0.3795 - val_loss: 0.4757
# Epoch 179/400
# 81/81 [==============================] - 2s 21ms/step - loss: 0.3767 - val_loss: 0.4756
# Epoch 180/400
# 81/81 [==============================] - 2s 22ms/step - loss: 0.3796 - val_loss: 0.4737
# Epoch 181/400
# 81/81 [==============================] - 2s 22ms/step - loss: 0.3757 - val_loss: 0.4757
# Epoch 182/400
# 81/81 [==============================] - 2s 22ms/step - loss: 0.3709 - val_loss: 0.4775
# Epoch 183/400
# 81/81 [==============================] - 2s 21ms/step - loss: 0.3718 - val_loss: 0.4819
# Epoch 184/400
# 81/81 [==============================] - 2s 21ms/step - loss: 0.3652 - val_loss: 0.4803
# Epoch 185/400
# 81/81 [==============================] - 2s 21ms/step - loss: 0.3691 - val_loss: 0.4741
# Epoch 186/400
# 81/81 [==============================] - 2s 21ms/step - loss: 0.3724 - val_loss: 0.4771
# Epoch 187/400
# 81/81 [==============================] - 2s 21ms/step - loss: 0.3653 - val_loss: 0.4779
# Epoch 188/400
# 81/81 [==============================] - 2s 22ms/step - loss: 0.3661 - val_loss: 0.4757
# Epoch 189/400
# 81/81 [==============================] - 2s 21ms/step - loss: 0.3665 - val_loss: 0.4723
# Epoch 190/400
# 81/81 [==============================] - 2s 21ms/step - loss: 0.3631 - val_loss: 0.4683
# Epoch 191/400
# 81/81 [==============================] - 2s 21ms/step - loss: 0.3659 - val_loss: 0.4780
# Epoch 192/400
# 81/81 [==============================] - 2s 21ms/step - loss: 0.3689 - val_loss: 0.4610
# Epoch 193/400
# 81/81 [==============================] - 2s 21ms/step - loss: 0.3638 - val_loss: 0.4650
# Epoch 194/400
# 81/81 [==============================] - 2s 21ms/step - loss: 0.3630 - val_loss: 0.4709
# Epoch 195/400
# 81/81 [==============================] - 2s 21ms/step - loss: 0.3637 - val_loss: 0.4680
# Epoch 196/400
# 81/81 [==============================] - 2s 21ms/step - loss: 0.3642 - val_loss: 0.4667
# Epoch 197/400
# 81/81 [==============================] - 2s 21ms/step - loss: 0.3600 - val_loss: 0.4661
# Epoch 198/400
# 81/81 [==============================] - 2s 21ms/step - loss: 0.3616 - val_loss: 0.4676
# Epoch 199/400
# 81/81 [==============================] - 2s 22ms/step - loss: 0.3631 - val_loss: 0.4655
# Epoch 200/400
# 81/81 [==============================] - 2s 21ms/step - loss: 0.3594 - val_loss: 0.4677
# Epoch 201/400
# 81/81 [==============================] - 2s 21ms/step - loss: 0.3636 - val_loss: 0.4673
# Epoch 202/400
# 81/81 [==============================] - 2s 22ms/step - loss: 0.3575 - val_loss: 0.4625
# Epoch 203/400
# 81/81 [==============================] - 2s 22ms/step - loss: 0.3639 - val_loss: 0.4649
# Epoch 204/400
# 81/81 [==============================] - 2s 22ms/step - loss: 0.3616 - val_loss: 0.4666
# Epoch 205/400
# 81/81 [==============================] - 2s 21ms/step - loss: 0.3589 - val_loss: 0.4656
# Epoch 206/400
# 81/81 [==============================] - 2s 21ms/step - loss: 0.3609 - val_loss: 0.4687
# Epoch 207/400
# 81/81 [==============================] - 2s 21ms/step - loss: 0.3580 - val_loss: 0.4692
# Epoch 208/400
# 81/81 [==============================] - 2s 21ms/step - loss: 0.3610 - val_loss: 0.4713
# Epoch 209/400
# 81/81 [==============================] - 2s 21ms/step - loss: 0.3635 - val_loss: 0.4694
# Epoch 210/400
# 81/81 [==============================] - 2s 21ms/step - loss: 0.3600 - val_loss: 0.4707
# Epoch 211/400
# 81/81 [==============================] - 2s 21ms/step - loss: 0.3615 - val_loss: 0.4718
# Epoch 212/400
# 81/81 [==============================] - 2s 22ms/step - loss: 0.3579 - val_loss: 0.4735
# Epoch 213/400
# 81/81 [==============================] - 2s 21ms/step - loss: 0.3619 - val_loss: 0.4708
# Epoch 214/400
# 81/81 [==============================] - 2s 22ms/step - loss: 0.3584 - val_loss: 0.4766
# Epoch 215/400
# 81/81 [==============================] - 2s 21ms/step - loss: 0.3595 - val_loss: 0.4709
# Epoch 216/400
# 81/81 [==============================] - 2s 21ms/step - loss: 0.3597 - val_loss: 0.4716
# Epoch 217/400
# 81/81 [==============================] - 2s 21ms/step - loss: 0.3601 - val_loss: 0.4703
# Epoch 218/400
# 81/81 [==============================] - 2s 21ms/step - loss: 0.3607 - val_loss: 0.4721
# Epoch 219/400
# 81/81 [==============================] - 2s 21ms/step - loss: 0.3587 - val_loss: 0.4696
# Epoch 220/400
# 81/81 [==============================] - 2s 21ms/step - loss: 0.3583 - val_loss: 0.4699
# Epoch 221/400
# 81/81 [==============================] - 2s 21ms/step - loss: 0.3601 - val_loss: 0.4731
# Epoch 222/400
# 81/81 [==============================] - 2s 22ms/step - loss: 0.3611 - val_loss: 0.4715
# Epoch 223/400
# 81/81 [==============================] - 2s 21ms/step - loss: 0.3583 - val_loss: 0.4642
# Epoch 224/400
# 81/81 [==============================] - 2s 21ms/step - loss: 0.3647 - val_loss: 0.4595
# Epoch 225/400
# 81/81 [==============================] - 2s 22ms/step - loss: 0.3582 - val_loss: 0.4696
# Epoch 226/400
# 81/81 [==============================] - 2s 21ms/step - loss: 0.3595 - val_loss: 0.4748
# Epoch 227/400
# 81/81 [==============================] - 2s 21ms/step - loss: 0.3589 - val_loss: 0.4710
# Epoch 228/400
# 81/81 [==============================] - 2s 21ms/step - loss: 0.3575 - val_loss: 0.4691
# Epoch 229/400
# 81/81 [==============================] - 2s 21ms/step - loss: 0.3615 - val_loss: 0.4771
# Epoch 230/400
# 81/81 [==============================] - 2s 21ms/step - loss: 0.3581 - val_loss: 0.4753
# Epoch 231/400
# 81/81 [==============================] - 2s 21ms/step - loss: 0.3568 - val_loss: 0.4759
# Epoch 232/400
# 81/81 [==============================] - 2s 21ms/step - loss: 0.3614 - val_loss: 0.4727
# Epoch 233/400
# 81/81 [==============================] - 2s 21ms/step - loss: 0.3611 - val_loss: 0.4728
# Epoch 234/400
# 81/81 [==============================] - 2s 21ms/step - loss: 0.3614 - val_loss: 0.4727
# Epoch 235/400
# 81/81 [==============================] - 2s 21ms/step - loss: 0.3575 - val_loss: 0.4717
# Epoch 236/400
# 81/81 [==============================] - 2s 21ms/step - loss: 0.3677 - val_loss: 0.4459
# Epoch 237/400
# 81/81 [==============================] - 2s 21ms/step - loss: 0.3631 - val_loss: 0.4620
# Epoch 238/400
# 81/81 [==============================] - 2s 21ms/step - loss: 0.3580 - val_loss: 0.4641
# Epoch 239/400
# 81/81 [==============================] - 2s 21ms/step - loss: 0.3569 - val_loss: 0.4655
# Epoch 240/400
# 81/81 [==============================] - 2s 22ms/step - loss: 0.3578 - val_loss: 0.4660
# Epoch 241/400
# 81/81 [==============================] - 2s 21ms/step - loss: 0.3603 - val_loss: 0.4663
# Epoch 242/400
# 81/81 [==============================] - 2s 21ms/step - loss: 0.4685 - val_loss: 0.5378
# Epoch 243/400
# 81/81 [==============================] - 2s 22ms/step - loss: 0.4764 - val_loss: 0.5377
# Epoch 244/400
# 81/81 [==============================] - 2s 22ms/step - loss: 0.4458 - val_loss: 0.5272
# Epoch 245/400
# 81/81 [==============================] - 2s 21ms/step - loss: 0.4358 - val_loss: 0.5220
# Epoch 246/400
# 81/81 [==============================] - 2s 21ms/step - loss: 0.4288 - val_loss: 0.5117
# Epoch 247/400
# 81/81 [==============================] - 2s 21ms/step - loss: 0.4249 - val_loss: 0.5033
# Epoch 248/400
# 81/81 [==============================] - 2s 21ms/step - loss: 0.4210 - val_loss: 0.5056
# Epoch 249/400
# 81/81 [==============================] - 2s 21ms/step - loss: 0.4185 - val_loss: 0.5001
# Epoch 250/400
# 81/81 [==============================] - 2s 21ms/step - loss: 0.4167 - val_loss: 0.4952
# Epoch 251/400
# 81/81 [==============================] - 2s 21ms/step - loss: 0.4111 - val_loss: 0.4922
# Epoch 252/400
# 81/81 [==============================] - 2s 21ms/step - loss: 0.4095 - val_loss: 0.4885
# Epoch 253/400
# 81/81 [==============================] - 2s 21ms/step - loss: 0.4008 - val_loss: 0.4860
# Epoch 254/400
# 81/81 [==============================] - 2s 21ms/step - loss: 0.4020 - val_loss: 0.4836
# Epoch 255/400
# 81/81 [==============================] - 2s 21ms/step - loss: 0.3975 - val_loss: 0.4804
# Epoch 256/400
# 81/81 [==============================] - 2s 21ms/step - loss: 0.3949 - val_loss: 0.4823
# Epoch 257/400
# 81/81 [==============================] - 2s 21ms/step - loss: 0.3930 - val_loss: 0.4811
# Epoch 258/400
# 81/81 [==============================] - 2s 21ms/step - loss: 0.3928 - val_loss: 0.4806
# Epoch 259/400
# 81/81 [==============================] - 2s 22ms/step - loss: 0.3882 - val_loss: 0.4815
# Epoch 260/400
# 81/81 [==============================] - 2s 22ms/step - loss: 0.3890 - val_loss: 0.4752
# Epoch 261/400
# 81/81 [==============================] - 2s 21ms/step - loss: 0.3868 - val_loss: 0.4808
# Epoch 262/400
# 81/81 [==============================] - 2s 21ms/step - loss: 0.3887 - val_loss: 0.4779
# Epoch 263/400
# 81/81 [==============================] - 2s 21ms/step - loss: 0.3859 - val_loss: 0.4836
# Epoch 264/400
# 81/81 [==============================] - 2s 21ms/step - loss: 0.3874 - val_loss: 0.4806
# Epoch 265/400
# 81/81 [==============================] - 2s 22ms/step - loss: 0.3898 - val_loss: 0.4853
# Epoch 266/400
# 81/81 [==============================] - 2s 21ms/step - loss: 0.
400
# 81/81 [==============================] - 2s 22ms/step - loss: 0.3711 - val_loss: 0.4568
# Epoch 386/400
# 81/81 [==============================] - 2s 22ms/step - loss: 0.3651 - val_loss: 0.4624
# Epoch 387/400
# 81/81 [==============================] - 2s 21ms/step - loss: 0.4156 - val_loss: 0.4761
# Epoch 388/400
# 81/81 [==============================] - 2s 21ms/step - loss: 0.4031 - val_loss: 0.4605
# Epoch 389/400
# 81/81 [==============================] - 2s 21ms/step - loss: 0.3748 - val_loss: 0.4459
# Epoch 390/400
# 81/81 [==============================] - 2s 21ms/step - loss: 0.3719 - val_loss: 0.4409
# Epoch 391/400
# 81/81 [==============================] - 2s 21ms/step - loss: 0.3652 - val_loss: 0.4405
# Epoch 392/400
# 81/81 [==============================] - 2s 22ms/step - loss: 0.3664 - val_loss: 0.4398
# Epoch 393/400
# 81/81 [==============================] - 2s 22ms/step - loss: 0.3648 - val_loss: 0.4417
# Epoch 394/400
# 81/81 [==============================] - 2s 21ms/step - loss: 0.3659 - val_loss: 0.4424
# Epoch 395/400
# 81/81 [==============================] - 2s 21ms/step - loss: 0.3635 - val_loss: 0.4459
# Epoch 396/400
# 81/81 [==============================] - 2s 21ms/step - loss: 0.3658 - val_loss: 0.4444
# Epoch 397/400
# 81/81 [==============================] - 2s 21ms/step - loss: 0.3633 - val_loss: 0.4423
# Epoch 398/400
# 81/81 [==============================] - 2s 21ms/step - loss: 0.3651 - val_loss: 0.4428
# Epoch 399/400
# 81/81 [==============================] - 2s 22ms/step - loss: 0.3600 - val_loss: 0.4436
# Epoch 400/400
# 81/81 [==============================] - 2s 21ms/step - loss: 0.3646 - val_loss: 0.4457

# %%
# Plot the training and validation loss per epoch.
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])

plt.xlabel('Epoch')
plt.ylabel('Mean Absolute Error Loss')
plt.title('Loss Over Time')
plt.legend(['Train','Valid'])

# %%
# Save model if required.
model.save("fuel_price_simple_lstm_final_400_epochs.h5")

# Load model from previous training run.
#model = tf.keras.models.load_model("fuel_price_wavenet_windows_v3.h5")

# %%
# Return the prediction sequence for individual historic input.
def predict_sequence(input_sequence):

    history_sequence = input_sequence.copy()
    pred_sequence = np.zeros((1,pred_steps,1)) # initialize output (pred_steps time steps)  
    
    for i in range(pred_steps):
        
        # record next time step prediction (last time step of model output) 
        last_step_pred = model.predict(history_sequence)
        pred_sequence[0,i,0] = last_step_pred
        
        # add the next time step prediction to the history sequence
        history_sequence = np.concatenate([history_sequence[:,1:,:], last_step_pred.reshape(-1,1,1)], axis=1)

        #print(last_step_pred.reshape(1,1,1).shape)
        #print(history_sequence.shape)

    return pred_sequence

# %%
single_input = train_input_data[1012:1013,:,:]
single_pred = model.predict(single_input)

print("Input shape: ",single_input.shape)
print("Prediction shape:",single_pred.shape)
print("Prediction example:", single_pred)

multi_pred = predict_sequence(single_input)
print("Prediction sequence shape:",multi_pred.shape)
# Out:
# Input shape:  (1, 600, 1)
# Prediction shape: (1, 1)
# Prediction example: [[2.385109]]
# Prediction sequence shape: (1, 60, 1)

# %%
# Function to plot single input, target and prediction.
def predict_and_plot(history_input_data, history_target_data, sample_ind, enc_tail_len=100):

    # Select a historic window from the validation time series. Must be 3D.
    history_series = history_input_data[sample_ind:sample_ind+1,:,:]

    # Returns the next X days predictions using the model.
    pred_series = predict_sequence(history_series)
    
    # Reshape history, predictions and targets from 3D to 2D arrays.
    history_series = history_series.reshape(-1,1)
    pred_series = pred_series.reshape(-1,1)   
    target_series = history_target_data[sample_ind,:,:1].reshape(-1,1) 

    # Concatenate the last steps of the history, plus first prediction - make graph look continuous!
    history_series_tail = np.concatenate([history_series[-enc_tail_len:],target_series[:1]])
    # Shape of the first dimension of history tail.
    x_history = history_series_tail.shape[0]
    
    plt.figure(figsize=(6,4))   
    
    # Plot history.
    plt.plot(range(1,x_history+1),history_series_tail)
    # Plot the targets.
    plt.plot(range(x_history,x_history+pred_steps),target_series,color='orange')
    # Plot the predictions.
    plt.plot(range(x_history,x_history+pred_steps),pred_series,color='teal',linestyle='--')
    
    plt.title('Historic Series Tail of Length %d, Target Series, and Predictions' % enc_tail_len)
    plt.legend(['Historic Series','Target Series','Predictions'])

# %%
# Check some plots on the training data.
predict_and_plot(train_input_data, train_target_data, 1018, 200) #107

# %%
# Check some plots on the validation data.
predict_and_plot(validation_input_data, validation_target_data, 173, 200)

# %%
# Return the prediction sequences for all historic inputs.
def predict_sequence_all(input_sequence):

    history_sequence = input_sequence.copy()

    # initialize output (pred_steps time steps)
    pred_sequence_all = np.zeros((history_sequence.shape[0],pred_steps,1))  
    
    for i in range(pred_steps):
        
        # record next time step prediction (last time step of model output) 
        last_step_pred = model.predict(history_sequence)#[:,-1,0]
        pred_sequence_all[:,i,:] = last_step_pred.reshape(history_sequence.shape[0],1)
        
        # add the next time step prediction to the history sequence        
        history_sequence = np.concatenate([history_sequence[:,1:,:], last_step_pred.reshape(-1,1,1)], axis=1)


    return pred_sequence_all

# %%
# Create array of all day predictions for all the historic data windows.

#pred_array_train = predict_sequence_all(train_input_data)
#print(pred_array_train.shape)
#print(train_target_data.shape)

pred_array_validation = predict_sequence_all(validation_input_data)
print("Shape of validation predictions array: ",pred_array_validation.shape)
print("Shape of validation targets array: ",validation_target_data.shape)
# Out:
# Shape of validation predictions array:  (1960, 60, 1)
# Shape of validation targets array:  (1960, 60, 1)

# %%
# Mean absolute error of the normalised data.
#print("Mean absolute error TRAIN = ",np.mean(np.abs(np.subtract(train_target_data[:10000],\
                                          #pred_array_train))))

print("Mean absolute error VAL normalised = ",np.mean(np.abs(np.subtract(validation_target_data[:10000],\
                                          pred_array_validation))))
# Out:
# Mean absolute error VAL normalised =  0.6058111119934034

# %%
# You need to back out the std dev and mean to get the price values.
def transform_to_price(series_array, train_series_mean, train_series_std):

    series_array = (series_array * train_series_std ) + train_series_mean
    series_array = series_array.reshape((series_array.shape[0],series_array.shape[1], 1))
    
    return series_array

# %%
# Transformation the normalised data back to price data.

#train_input_price = transform_to_price(train_input_data, train_series_mean, train_series_std)
#train_predictions_price = transform_to_price(pred_array_train, train_series_mean, train_series_std)
#train_targets_price = transform_to_price(train_target_data, train_series_mean, train_series_std)

validation_input_price = transform_to_price(validation_input_data, train_series_mean, train_series_std)
validation_predictions_price = transform_to_price(pred_array_validation, train_series_mean, train_series_std)
validation_targets_price = transform_to_price(validation_target_data, train_series_mean, train_series_std)

# %%
# Function to plot input, target and prediction from array of mulitple examples.
def predict_and_plot2(input_data, target_data, prediction_data, sample_ind, enc_tail_len=100):

    # Select a historic window from the validation time series. Must be 3D.
    history_series = input_data[sample_ind:sample_ind+1,:,:]

    # Select the next X days predictions.
    pred_series = prediction_data[sample_ind:sample_ind+1,:,:]

    # Reshape history, predictions and targets from 3D to 2D arrays.
    history_series = history_series.reshape(-1,1)
    pred_series = pred_series.reshape(-1,1)   
    target_series = target_data[sample_ind:sample_ind+1,:,:1].reshape(-1,1) 

    # Concatenate the last steps of the history, plus first prediction - make graph look continuous!
    history_series_tail = np.concatenate([history_series[-enc_tail_len:],target_series[:1]])
    # Shape of the first dimension of history tail.
    x_history = history_series_tail.shape[0]
    
    plt.figure(figsize=(6,4))   
    
    # Plot history.
    plt.plot(range(1,x_history+1),history_series_tail)
    # Plot the targets.
    plt.plot(range(x_history,x_history+pred_steps),target_series,color='orange')
    # Plot the predictions.
    plt.plot(range(x_history,x_history+pred_steps),pred_series,color='teal',linestyle='--')
    
    plt.title('Historic Series Tail of Length %d, Target Series, and Predictions' % enc_tail_len)
    plt.legend(['Historic Series','Target Series','Predictions'])

# %%
# Plot predictions versus targets for selected TRAIN data.
#predict_and_plot2(train_input_price[:,:-59], train_targets_price, train_predictions_price, 1000,500)

# %%
# Mean absolute error.
#print("Mean absolute error TRAIN = ",np.mean(np.abs(np.subtract(train_targets_price,\
                                          #train_predictions_price))))

# Mean absolute percentage error.
#print("Mean absolute % error TRAIN = ", np.mean( np.abs(np.subtract(train_targets_price,\
                  #train_predictions_price)/train_targets_price)*100 ) )

# %%
# Plot predictions versus targets for selected VALIDATION data.
predict_and_plot2(validation_input_price, validation_targets_price, validation_predictions_price, 519 ,200)

# %%
# Mean absolute error.
print("Mean absolute error VALIDATION = ",np.mean(np.abs(np.subtract(validation_targets_price,\
                                          validation_predictions_price))))

# Mean absolute percentage error.
print("Mean absolute % error VALIDATION = ", np.mean( np.abs(np.subtract(validation_targets_price,\
                  validation_predictions_price)/validation_targets_price)*100 ) )
# Out:
# Mean absolute error VALIDATION =  6.373318304667883
# Mean absolute % error VALIDATION =  4.480354502084759

# %%
# Normalise test historic data with train std and mean.
test_input_data = transform_series_other(test_series[:,:window], train_series_mean, train_series_std)

# Normalise test target data with train std and mean.
test_target_data = transform_series_other(test_series[:,window:], train_series_mean, train_series_std)

# %%
# Plot predictions versus targets for selected TEST data.
predict_and_plot(test_input_data, test_target_data, 514, 200)

# %%
# Run the predictions on the test input data.
pred_array_test = predict_sequence_all(test_input_data)
print("Shape of test predictions: ",pred_array_test.shape)
print("Shape of test targets: ",test_target_data.shape)
# Out:
# Shape of test predictions:  (1961, 60, 1)
# Shape of test targets:  (1961, 60, 1)

# %%
# De-normalise the test data.
test_input_price = transform_to_price(test_input_data, train_series_mean, train_series_std)
test_predictions_price = transform_to_price(pred_array_test, train_series_mean, train_series_std)
test_targets_price = transform_to_price(test_target_data, train_series_mean, train_series_std)

# %%
# Plot predictions versus targets for selected TEST data.
predict_and_plot2(test_input_price, test_targets_price, test_predictions_price, 1117, 200)

# %%
# Mean absolute error.
print("Mean absolute error TEST = ",np.mean(np.abs(np.subtract(test_targets_price,\
                                          test_predictions_price))))

# Mean absolute percentage error.
print("Mean absolute % error TEST = ", np.mean( np.abs(np.subtract(test_targets_price,\
                  test_predictions_price)/test_targets_price)*100 ) )
# Out:
# Mean absolute error TEST =  6.367769694792073
# Mean absolute % error TEST =  4.484649149417865
